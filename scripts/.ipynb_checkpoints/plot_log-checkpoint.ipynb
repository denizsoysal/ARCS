# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("/home/brendan/Desktop/iiwase_log.csv", header=None, 
                names=["time", "activity", "stream", "signal", "value"], parse_dates=["time"])
df.head()
# Out:
#                       time          activity stream            signal  \
# 0  2023-01-17 13:58:22.228   iiwa_controller   info          wrench_z
# 1  2023-01-17 13:58:22.228   iiwa_controller   info            ek_bar
# 2  2023-01-17 13:58:22.228   iiwa_controller   info              bias
# 3  2023-01-17 13:58:22.228   iiwa_controller   info              gain
# 4  2023-01-17 13:58:22.228   iiwa_controller   info           control
# 5  2023-01-17 13:58:22.228   iiwa_controller   info   meas_jnt_pos[0]
# 6  2023-01-17 13:58:22.228   iiwa_controller   info   meas_jnt_pos[1]
# 7  2023-01-17 13:58:22.228   iiwa_controller   info   meas_jnt_pos[2]
# 8  2023-01-17 13:58:22.228   iiwa_controller   info   meas_jnt_pos[3]
# 9  2023-01-17 13:58:22.228   iiwa_controller   info   meas_jnt_pos[4]
# 10 2023-01-17 13:58:22.228   iiwa_controller   info   meas_jnt_pos[5]
# 11 2023-01-17 13:58:22.228   iiwa_controller   info   meas_jnt_pos[6]
# ...

# %%
df["time"][23] - df["time"][0]
# Out:
# Timedelta('0 days 00:00:00.032000')
